# %% [markdown]
# # Location for opening a new Indian restaurant 5 kilo meters from New york city CBD.

# %% [markdown]
# # Introduction/Business Problem

# %%
# An enthusiast wants to open an Indian restaurant within 5 kms from New York CBD. 
# Being a new entrepreneur in this domain , he/she wants a visualization map of Indian restaurant 's locations within this area.
# And he wants a suggestive map location  to establish the business,where there are non or few Indian restaurant's located.

# %% [markdown]
# ### Data section

# %%
# Data Used: The latitude and longitude of New York city  is used to make a call to the 4 square API  with search query  as Indian restaurant and within a radius of 5 Km's.
# For example: The search query for New York city for Indian restaurant's within a radius of 5 Kms from CBD with a search  limit of 5000 restaurants will be:
# 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %% [markdown]
#  ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '22CNRY0G2PZV00WLW12BFAC5KG0ZPB1CDZ2HQ05HNTO203UL' # your Foursquare ID
CLIENT_SECRET = 'LRV2TWX04RQ4WTTGSVLJS4MBTVW5GRUOK4ASBAAOH1JPGHEN' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 3000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 22CNRY0G2PZV00WLW12BFAC5KG0ZPB1CDZ2HQ05HNTO203UL
# CLIENT_SECRET:LRV2TWX04RQ4WTTGSVLJS4MBTVW5GRUOK4ASBAAOH1JPGHEN

# %% [markdown]
# ### Get the latitude and longitiude of New York

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %% [markdown]
# ### Search four sqaure API using serach query as Indian restaurant,radius=5000 meters and a limit of 5000 restuarants

# %%
search_query = 'Indian restaurant'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Indian restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=22CNRY0G2PZV00WLW12BFAC5KG0ZPB1CDZ2HQ05HNTO203UL&client_secret=LRV2TWX04RQ4WTTGSVLJS4MBTVW5GRUOK4ASBAAOH1JPGHEN&ll=40.7127281,-74.0060152&v=20180604&query=Indian restaurant&radius=5000&limit=3000'

# %%
# assign relevant part of JSON to venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60bb1663c3d6c5781dcce3f6'},
#  'response': {'venues': [{'id': '4116be80f964a520f90b1fe3',
#     'name': 'Panna II Garden Indian Restaurant',
#     'location': {'address': '93 1st Ave',
#      'crossStreet': 'btwn 5th & 6th St',
#      'lat': 40.726272990045985,
#      'lng': -73.98627301759028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.726272990045985,
#        'lng': -73.98627301759028},
#       {'label': 'entrance', 'lat': 40.726254, 'lng': -73.986488}],
#      'distance': 2246,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['93 1st Ave (btwn 5th & 6th St)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2208366',
#      'url': 'https://www.seamless.com/menu/panna2-garden-indian-restaurant-93-1st-avenue-new-york/2208366?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2208366',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '149505937'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '506a2625498e3c434686abbc',
#     'name': 'Asya Indian Restaurant',
#     'location': {'address': '46 Henry St',
#      'lat': 40.699607,
#      'lng': -73.99211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.699607,
#        'lng': -73.99211}],
#      'distance': 1873,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['46 Henry St',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '266126',
#      'url': 'https://www.seamless.com/menu/asya-46-henry-st-brooklyn/266126?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=266126',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '94617937'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4c17b29b838020a1fd0de361',
#     'name': "Bombay's Indian Restaurant",
#     'location': {'address': '60 Pearl St',
#      'crossStreet': 'Broad St.',
#      'lat': 40.70356930142193,
#      'lng': -74.01114087858141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70356930142193,
#        'lng': -74.01114087858141},
#       {'label': 'entrance', 'lat': 40.703503, 'lng': -74.011109}],
#      'distance': 1107,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['60 Pearl St (Broad St.)',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '263979',
#      'url': 'https://www.seamless.com/menu/bombays-indian-restaurant-60-pearl-st-new-york/263979?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=263979',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '93243558'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4d0e6159bf0c8eec2188282a',
#     'name': 'Indian Restaurant',
#     'location': {'address': '369 Broome St',
#      'lat': 40.71997833251953,
#      'lng': -73.99590301513672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71997833251953,
#        'lng': -73.99590301513672}],
#      'distance': 1174,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['369 Broome St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4f32a9c119836c91c7eda319',
#     'name': 'Indian Restaurant',
#     'location': {'address': '338 9th Ave',
#      'lat': 40.7503662109375,
#      'lng': -73.99813842773438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7503662109375,
#        'lng': -73.99813842773438}],
#      'distance': 4242,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['338 9th Ave',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4e4de5fbbd4101d0d79da9d0',
#     'name': 'Dhaka Indian Restaurant',
#     'location': {'address': '148 Atlantic Ave',
#      'lat': 40.690147399902344,
#      'lng': -73.99492645263672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.690147399902344,
#        'lng': -73.99492645263672}],
#      'distance': 2682,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['148 Atlantic Ave',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '52f18573498ec2c34e830ffd',
#     'name': "Kanan's Indian Restaurant",
#     'location': {'address': '452 3rd Ave',
#      'crossStreet': '9th Street',
#      'lat': 40.671890999999995,
#      'lng': -73.99094000000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.671890999999995,
#        'lng': -73.99094000000001},
#       {'label': 'entrance', 'lat': 40.671842, 'lng': -73.990867}],
#      'distance': 4720,
#      'postalCode': '11215',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['452 3rd Ave (9th Street)',
#       'Brooklyn, NY 11215',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '288581',
#      'url': 'https://www.seamless.com/menu/kanan-indian-restaurant-452-3rd-ave-brooklyn/288581?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=288581',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4a7a2112f964a5209ee81fe3',
#     'name': 'Joy Indian Restaurant',
#     'location': {'address': '301 Flatbush Ave',
#      'crossStreet': 'Prospect Pl',
#      'lat': 40.67878769589125,
#      'lng': -73.97358071122206,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.67878769589125,
#        'lng': -73.97358071122206},
#       {'label': 'entrance', 'lat': 40.67882, 'lng': -73.973453}],
#      'distance': 4665,
#      'postalCode': '11217',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['301 Flatbush Ave (Prospect Pl)',
#       'Brooklyn, NY 11217',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2251194',
#      'url': 'https://www.seamless.com/menu/joy-indian-restaurant-301-flatbush-ave-brooklyn/2251194?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2251194',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4c673e729cb82d7f024593d2',
#     'name': 'Sapid Indian Restaurant',
#     'location': {'address': '595 Washington Ave',
#      'crossStreet': 'btw Pacific & Dean',
#      'lat': 40.679788646487594,
#      'lng': -73.96416970895852,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.679788646487594,
#        'lng': -73.96416970895852}],
#      'distance': 5091,
#      'postalCode': '11238',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['595 Washington Ave (btw Pacific & Dean)',
#       'Brooklyn, NY 11238',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '81552',
#      'url': 'https://www.seamless.com/menu/sapid-indian-food-595-washington-ave-brooklyn/81552?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=81552',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '5023ff6ce4b06e8a945ea64a',
#     'name': 'Joy Curry & Tandoor Indian Restaurant',
#     'location': {'address': '32 W 39th St',
#      'crossStreet': '6th Ave',
#      'lat': 40.75238509631068,
#      'lng': -73.98404513685537,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75238509631068,
#        'lng': -73.98404513685537}],
#      'distance': 4787,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['32 W 39th St (6th Ave)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '93547141'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4c4890da1879c9b6cce6e143',
#     'name': 'New Shezan Restaurant',
#     'location': {'address': '183 Church St',
#      'crossStreet': 'btwn Duane & Reade St.',
#      'lat': 40.71578949233164,
#      'lng': -74.00722736485034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71578949233164,
#        'lng': -74.00722736485034},
#       {'label': 'entrance', 'lat': 40.715683, 'lng': -74.007172}],
#      'distance': 355,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['183 Church St (btwn Duane & Reade St.)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1237998',
#      'url': 'https://www.seamless.com/menu/sheezan-restaurant-183-church-st-new-york/1237998?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1237998',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '5072fe2eb0ed0fcce2497f30',
#     'name': 'Indian Biryani Delights (Cart)',
#     'location': {'address': 'Water St',
#      'crossStreet': 'btwn Maiden Lane & Pine St',
#      'lat': 40.71316451366987,
#      'lng': -74.01021890317702,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71316451366987,
#        'lng': -74.01021890317702}],
#      'distance': 358,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Water St (btwn Maiden Lane & Pine St)',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '573f435b498e03b8bb8582c7',
#     'name': 'Indian King Briyani House',
#     'location': {'address': '140 Broadway',
#      'lat': 40.70916650382646,
#      'lng': -74.01062632424185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70916650382646,
#        'lng': -74.01062632424185}],
#      'distance': 555,
#      'postalCode': '10005',
#      'cc': 'US',
#      'neighborhood': 'Financial District',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['140 Broadway',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2510164',
#      'url': 'https://www.seamless.com/menu/indian-king-birayni-house-140-broadway-new-york/2510164?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2510164',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4bbb9dbded7776b0e1ad3e51',
#     'name': 'Tamarind TriBeCa',
#     'location': {'address': '99 Hudson St',
#      'crossStreet': 'at Franklin St',
#      'lat': 40.71921117375622,
#      'lng': -74.00872657957527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71921117375622,
#        'lng': -74.00872657957527},
#       {'label': 'entrance', 'lat': 40.719084, 'lng': -74.008899}],
#      'distance': 757,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['99 Hudson St (at Franklin St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2488438',
#      'url': 'https://www.seamless.com/menu/tamarind-99-hudson-st-new-york/2488438?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2488438',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '49f125dcf964a52091691fe3',
#     'name': "O'Hara's Restaurant & Pub",
#     'location': {'address': '120 Cedar St',
#      'crossStreet': 'at Greenwich St.',
#      'lat': 40.70989378141622,
#      'lng': -74.01283563128297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70989378141622,
#        'lng': -74.01283563128297},
#       {'label': 'entrance', 'lat': 40.709559, 'lng': -74.012621}],
#      'distance': 656,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Cedar St (at Greenwich St.)',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2086580',
#      'url': 'https://www.seamless.com/menu/oharas-restaurant-and-pub-120-cedar-street-new-york/2086580?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2086580',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '93216281'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4a948b83f964a520f32120e3',
#     'name': 'Indian Express',
#     'location': {'address': '18 Murray St',
#      'crossStreet': 'Church St.',
#      'lat': 40.71341323852539,
#      'lng': -74.00846862792969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71341323852539,
#        'lng': -74.00846862792969}],
#      'distance': 220,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 Murray St (Church St.)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '510aad1ae4b0bfb2583169b9',
#     'name': 'A Saffron Thread Fresh Indian',
#     'location': {'address': '98 Chambers St',
#      'crossStreet': 'at Church St',
#      'lat': 40.71482256030567,
#      'lng': -74.00768924078284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71482256030567,
#        'lng': -74.00768924078284}],
#      'distance': 272,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['98 Chambers St (at Church St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '275521',
#      'url': 'https://www.seamless.com/menu/a-saffron-thread-98-chambers-st-new-york/275521?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=275521',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '432263795'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '45e5c256f964a52046431fe3',
#     'name': 'Mudville Restaurant & Tap House',
#     'location': {'address': '126 Chambers St',
#      'crossStreet': 'btwn W Broadway & Church St',
#      'lat': 40.71520852817451,
#      'lng': -74.00892327116395,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.715239,
#        'lng': -74.008849},
#       {'label': 'display',
#        'lat': 40.71520852817451,
#        'lng': -74.00892327116395}],
#      'distance': 369,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['126 Chambers St (btwn W Broadway & Church St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14c941735',
#       'name': 'Wings Joint',
#       'pluralName': 'Wings Joints',
#       'shortName': 'Wings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '299726',
#      'url': 'https://www.seamless.com/menu/mudville-restaurant-126-chambers-st-new-york/299726?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299726',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '43156651'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4b4fdfc8f964a520801827e3',
#     'name': 'TJ Byrnes Bar and Restaurant',
#     'location': {'address': '77 Fulton St',
#      'crossStreet': 'Gold St',
#      'lat': 40.70923312629616,
#      'lng': -74.00374736164414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70923312629616,
#        'lng': -74.00374736164414}],
#      'distance': 433,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['77 Fulton St (Gold St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '64746',
#      'url': 'https://www.seamless.com/menu/tj-byrnes-77-fulton-st-new-york/64746?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=64746',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '131643631'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '574eab2a498e3f5530cfdbca',
#     'name': 'Indian Beautiful Art (IBA) Crafts PVT Ltd',
#     'location': {'address': '100 Church St',
#      'lat': 40.71228057311295,
#      'lng': -74.01012897491455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71228057311295,
#        'lng': -74.01012897491455}],
#      'distance': 350,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 Church St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '5d18e90b96ba5e00232c527f',
#     'name': 'Bismilla Indian Biryani House',
#     'location': {'lat': 40.715357202741,
#      'lng': -74.01131492125047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715357202741,
#        'lng': -74.01131492125047}],
#      'distance': 534,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10007', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '574e8ba2cd10da9c722374fb',
#     'name': 'Indian Beautiful Art (IBA) Crafts PVT Ltd',
#     'location': {'address': '100 Church St',
#      'lat': 40.71613521878094,
#      'lng': -74.00660991668701,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71613521878094,
#        'lng': -74.00660991668701}],
#      'distance': 382,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 Church St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f4941735',
#       'name': 'Design Studio',
#       'pluralName': 'Design Studios',
#       'shortName': 'Design',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/design_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '43bfd385f964a520232d1fe3',
#     'name': 'Waverly Restaurant',
#     'location': {'address': '385 Avenue of the Americas',
#      'crossStreet': 'at Waverly Pl.',
#      'lat': 40.73301202815689,
#      'lng': -74.00012444986078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73301202815689,
#        'lng': -74.00012444986078}],
#      'distance': 2312,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['385 Avenue of the Americas (at Waverly Pl.)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '64940',
#      'url': 'https://www.seamless.com/menu/waverly-restaurant-385-6th-ave-new-york/64940?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=64940',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4b87d979f964a5201bcf31e3',
#     'name': "McDonald's",
#     'location': {'address': '102 1st Ave',
#      'crossStreet': 'btwn 5th & 6th St',
#      'lat': 40.7265041,
#      'lng': -73.9858036,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.726483,
#        'lng': -73.985908},
#       {'label': 'display', 'lat': 40.7265041, 'lng': -73.9858036}],
#      'distance': 2293,
#      'postalCode': '10009',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['102 1st Ave (btwn 5th & 6th St)',
#       'New York, NY 10009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1339682',
#      'url': 'https://www.seamless.com/menu/mcdonalds-102-1st-avenue-new-york/1339682?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1339682',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4bc238adf8219c744286b410',
#     'name': "Amore's Pizza Restaurant",
#     'location': {'address': '147 Chambers St',
#      'crossStreet': 'Hudson Street',
#      'lat': 40.715859606149245,
#      'lng': -74.00988835781403,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715859606149245,
#        'lng': -74.00988835781403},
#       {'label': 'entrance', 'lat': 40.715854, 'lng': -74.009749}],
#      'distance': 477,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['147 Chambers St (Hudson Street)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1431324',
#      'url': 'https://www.seamless.com/menu/cafe-amores-pizzeria-ristorante-147-chambers-st-new-york/1431324?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1431324',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '3fd66200f964a5202feb1ee3',
#     'name': 'Kaña Tapas Bar & Restaurant',
#     'location': {'address': '324 Spring St.',
#      'crossStreet': 'btw Greenwhich and Washington',
#      'lat': 40.726028963162705,
#      'lng': -74.00928005636852,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.726028963162705,
#        'lng': -74.00928005636852},
#       {'label': 'entrance', 'lat': 40.725913, 'lng': -74.009409}],
#      'distance': 1506,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'South Village',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['324 Spring St. (btw Greenwhich and Washington)',
#       'South Village, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2218904',
#      'url': 'https://www.seamless.com/menu/kana-tapas-bar-324-spring-st-new-york/2218904?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2218904',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '45464786'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '56fd4c5e498e389de05f8b85',
#     'name': 'Wing Kee WK Restaurant 榮記飯店 (former 69)',
#     'location': {'address': '69 Bayard St',
#      'crossStreet': 'Mott Street And Elizabeth Street',
#      'lat': 40.71556547601636,
#      'lng': -73.99825798501342,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71556547601636,
#        'lng': -73.99825798501342}],
#      'distance': 726,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['69 Bayard St (Mott Street And Elizabeth Street)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '3fd66200f964a5207cf11ee3',
#     'name': "Junior's Restaurant",
#     'location': {'address': '386 Flatbush Avenue Ext',
#      'crossStreet': 'at DeKalb Ave',
#      'lat': 40.69001145156075,
#      'lng': -73.98173375415745,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.69001145156075,
#        'lng': -73.98173375415745}],
#      'distance': 3254,
#      'postalCode': '11201',
#      'cc': 'US',
#      'neighborhood': 'Downtown Brooklyn',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['386 Flatbush Avenue Ext (at DeKalb Ave)',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '291315',
#      'url': 'https://www.seamless.com/menu/juniors-restaurant-386-flatbush-ave-ext-brooklyn/291315?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=291315',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '66852513'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4c00acf98c1076b004982071',
#     'name': 'Gold Flower Restaurant',
#     'location': {'address': '9 Doyers St',
#      'lat': 40.714351,
#      'lng': -73.998213,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714351,
#        'lng': -73.998213},
#       {'label': 'entrance', 'lat': 40.714397, 'lng': -73.998144}],
#      'distance': 682,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['9 Doyers St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4c136388a1010f476c874a18',
#     'name': 'East Broadway Restaurant',
#     'location': {'address': '94 E Broadway',
#      'crossStreet': 'at Eldridge ST',
#      'lat': 40.713954,
#      'lng': -73.993579,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713954,
#        'lng': -73.993579},
#       {'label': 'entrance', 'lat': 40.713879, 'lng': -73.993569}],
#      'distance': 1058,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['94 E Broadway (at Eldridge ST)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '54a4690e498e43a77f503eba',
#     'name': 'National Museum of the American Indian Museum Store',
#     'location': {'address': '1 Bowling Grn',
#      'lat': 40.704048,
#      'lng': -74.013737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.704048,
#        'lng': -74.013737},
#       {'label': 'entrance', 'lat': 40.703691, 'lng': -74.013749}],
#      'distance': 1165,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Bowling Grn',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b1b',
#       'name': 'Souvenir Shop',
#       'pluralName': 'Souvenir Shops',
#       'shortName': 'Souvenir Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4b12cb6ff964a5204a8e23e3',
#     'name': 'Ruchi Indian Cuisine',
#     'location': {'address': '120 Cedar St',
#      'crossStreet': 'btwn Greenwich St. & Trinity Pl.',
#      'lat': 40.70996196046026,
#      'lng': -74.01296935042234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70996196046026,
#        'lng': -74.01296935042234}],
#      'distance': 662,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Cedar St (btwn Greenwich St. & Trinity Pl.)',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '79935',
#      'url': 'https://www.seamless.com/menu/ruchi-120-cedar-st-new-york/79935?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=79935',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '337710444'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4b88199af964a520e6df31e3',
#     'name': 'Win Won Restaurant',
#     'location': {'address': '10 Liberty Pl',
#      'crossStreet': 'Maiden Lane',
#      'lat': 40.709193,
#      'lng': -74.009344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.709193,
#        'lng': -74.009344},
#       {'label': 'entrance', 'lat': 40.709177, 'lng': -74.009278}],
#      'distance': 483,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Liberty Pl (Maiden Lane)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520ece31ee3',
#     'name': 'Golden Unicorn Restaurant 麒麟金閣',
#     'location': {'address': '18 E Broadway',
#      'crossStreet': 'at Catherine St',
#      'lat': 40.713628504646834,
#      'lng': -73.99723023176193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713628504646834,
#        'lng': -73.99723023176193}],
#      'distance': 748,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 E Broadway (at Catherine St)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2197825',
#      'url': 'https://www.seamless.com/menu/golden-unicorn-broadway-18-e-broadway-new-york/2197825?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2197825',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '72966848'},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4b44db0bf964a5204dfe25e3',
#     'name': 'Amin Indian Cuisine',
#     'location': {'address': '235 Dekalb Ave',
#      'crossStreet': 'at Clermont Ave',
#      'lat': 40.68953511109607,
#      'lng': -73.96978773811158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.68953511109607,
#        'lng': -73.96978773811158}],
#      'distance': 4001,
#      'postalCode': '11205',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['235 Dekalb Ave (at Clermont Ave)',
#       'Brooklyn, NY 11205',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '3fd66200f964a5209ae31ee3',
#     'name': "Arturo's Restaurant",
#     'location': {'address': '106 W Houston St',
#      'crossStreet': 'at Thompson St.',
#      'lat': 40.727407,
#      'lng': -74.000378,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.727407,
#        'lng': -74.000378},
#       {'label': 'entrance', 'lat': 40.727385, 'lng': -74.000407}],
#      'distance': 1701,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['106 W Houston St (at Thompson St.)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2083829',
#      'url': 'https://www.seamless.com/menu/arturos-restaurant-106-west-houston-street-new-york/2083829?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2083829',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '3fd66200f964a5204de41ee3',
#     'name': 'Frank Restaurant',
#     'location': {'address': '88 2nd Ave',
#      'crossStreet': 'at E 5th St',
#      'lat': 40.7269388318875,
#      'lng': -73.9888987815173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7269388318875,
#        'lng': -73.9888987815173}],
#      'distance': 2141,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['88 2nd Ave (at E 5th St)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '301204',
#      'url': 'https://www.seamless.com/menu/frank-restaurant-88-2nd-ave-new-york/301204?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=301204',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '5730b7a9498ef7b05c09c07f',
#     'name': "Baluchi's Indian",
#     'location': {'address': '176 Church Street',
#      'crossStreet': 'between Duane and Reade Streets',
#      'lat': 40.71567153930664,
#      'lng': -74.00765228271484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71567153930664,
#        'lng': -74.00765228271484}],
#      'distance': 355,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['176 Church Street (between Duane and Reade Streets)',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4b9c3bc7f964a5206d5736e3',
#     'name': 'East Boat Seafood Restaurant',
#     'location': {'address': '72 Kenmare St',
#      'lat': 40.72095489501953,
#      'lng': -73.99629974365234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72095489501953,
#        'lng': -73.99629974365234}],
#      'distance': 1229,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['72 Kenmare St',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '5632cf63498e155da31ebd2b',
#     'name': "Chili's Indian Cusine",
#     'location': {'address': '123 Allen St',
#      'crossStreet': 'btwn Delancey St & Rivington St',
#      'lat': 40.71972045796349,
#      'lng': -73.99013369094253,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71972045796349,
#        'lng': -73.99013369094253}],
#      'distance': 1549,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['123 Allen St (btwn Delancey St & Rivington St)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfdd',
#       'name': 'North Indian Restaurant',
#       'pluralName': 'North Indian Restaurants',
#       'shortName': 'North Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4e4463cf52b18fcc799a9761',
#     'name': '88 Reach House chinese restaurant',
#     'location': {'address': '88 Division St',
#      'crossStreet': 'Eldrige street',
#      'lat': 40.714468,
#      'lng': -73.993727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714468,
#        'lng': -73.993727}],
#      'distance': 1054,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['88 Division St (Eldrige street)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '58aa398b14fb41097a0cf923',
#     'name': 'Great Fortune Chinese Restaurant 聚旺茶餐廳',
#     'location': {'address': '5 Catherine St',
#      'crossStreet': 'btwn E Broadway & Chatham Sq',
#      'lat': 40.713875,
#      'lng': -73.99728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713875,
#        'lng': -73.99728}],
#      'distance': 748,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Catherine St (btwn E Broadway & Chatham Sq)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#       'name': 'Cantonese Restaurant',
#       'pluralName': 'Cantonese Restaurants',
#       'shortName': 'Cantonese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '5e71cb23abf70b00087b749e',
#     'name': 'Vatan Pure Vegetarian Indian Cuisine',
#     'location': {'address': '808 Newark Ave',
#      'lat': 40.73560333251953,
#      'lng': -74.06661224365234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73560333251953,
#        'lng': -74.06661224365234}],
#      'distance': 5711,
#      'postalCode': '07306',
#      'cc': 'US',
#      'city': 'Jersey City',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['808 Newark Ave',
#       'Jersey City, NJ 07306',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '82033',
#      'url': 'https://www.grubhub.com/restaurant/vatan-pure-vegetarian-indian-cuisine-839-newark-ave-jersey-city/82033?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=82033',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '575808cf38fa9ce070c7ce1b',
#     'name': 'Su Hang Restaurant',
#     'location': {'address': '103 Washington St Apt 2',
#      'crossStreet': 'Rector St',
#      'lat': 40.7083625793457,
#      'lng': -74.01404571533203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7083625793457,
#        'lng': -74.01404571533203}],
#      'distance': 833,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['103 Washington St Apt 2 (Rector St)',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '40fc6080f964a520040b1fe3',
#     'name': 'Romi Restaurant & Lounge',
#     'location': {'address': '19 Rector St',
#      'crossStreet': 'at Washington St.',
#      'lat': 40.707969665527344,
#      'lng': -74.01377868652344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707969665527344,
#        'lng': -74.01377868652344}],
#      'distance': 842,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['19 Rector St (at Washington St.)',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '575dea4c498e2739e43a27e2',
#     'name': 'Aahar Indian Cuisine',
#     'location': {'address': '10 Murray St',
#      'crossStreet': 'Broadway',
#      'lat': 40.71330656515891,
#      'lng': -74.00799405698501,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71330656515891,
#        'lng': -74.00799405698501}],
#      'distance': 178,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Murray St (Broadway)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '333939',
#      'url': 'https://www.seamless.com/menu/aahar-indian-cuisine-10-murray-st-new-york/333939?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=333939',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4f451ae719836ed00198a204',
#     'name': 'China Restaurant',
#     'location': {'address': '50 Henry St',
#      'lat': 40.71271514892578,
#      'lng': -73.99552917480469,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.712877,
#        'lng': -73.995203},
#       {'label': 'display',
#        'lat': 40.71271514892578,
#        'lng': -73.99552917480469}],
#      'distance': 884,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['50 Henry St',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4a598897f964a52071b91fe3',
#     'name': 'Hadramout Restaurant',
#     'location': {'address': '172 Atlantic Ave',
#      'crossStreet': 'btwn Court & Clinton St.',
#      'lat': 40.69003033686175,
#      'lng': -73.99378361748528,
#      'distance': 2729,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['172 Atlantic Ave (btwn Court & Clinton St.)',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '4ae015bff964a5202b7e21e3',
#     'name': 'Swagat Indian',
#     'location': {'address': '205 W 29th St',
#      'crossStreet': '7th Ave',
#      'lat': 40.74804551427938,
#      'lng': -73.99310765459191,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74804551427938,
#        'lng': -73.99310765459191}],
#      'distance': 4079,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['205 W 29th St (7th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '65014',
#      'url': 'https://www.seamless.com/menu/swagat-indian-restaurant-205-w-29th-st-new-york/65014?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=65014',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1622873699',
#     'hasPerk': False},
#    {'id': '50a5221fe4b0dea0468d43d1',
#     'name': 'smart indian cuisine',
#     'location': {'address': '53 Nassau St',
#      'crossStreet': 'maiden lane & liberty',
#      'lat': 40.709022,
#      'lng': -74.009117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.709022,
#        'lng': -74.009117},
#       {'label': 'entrance', 'lat': 40.708986, 'lng': -74.009055}],
#      'distance': 488,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['53 Nassau St (maiden lane & liberty)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1622873699',
#     'hasPerk': False}]}}

# %% [markdown]
# ###  Get relevant part of JSON and transform it into a pandas dataframe

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-14-a1687cb1d013>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                               name  \
# 0  4116be80f964a520f90b1fe3  Panna II Garden Indian Restaurant
# 1  506a2625498e3c434686abbc             Asya Indian Restaurant
# 2  4c17b29b838020a1fd0de361         Bombay's Indian Restaurant
# 3  4d0e6159bf0c8eec2188282a                  Indian Restaurant
# 4  4f32a9c119836c91c7eda319                  Indian Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1622873699    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1622873699    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1622873699    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1622873699    False
# 4  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1622873699    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# 0       93 1st Ave    btwn 5th & 6th St     40.726273    -73.986273
# 1      46 Henry St                  NaN     40.699607    -73.992110
# 2      60 Pearl St            Broad St.     40.703569    -74.011141
# 3    369 Broome St                  NaN     40.719978    -73.995903
# 4      338 9th Ave                  NaN     40.750366    -73.998138
#
#                              location.labeledLatLngs  ...  location.country  \
# 0  [{'label': 'display', 'lat': 40.72627299004598...  ...     United States
# 1  [{'label': 'display', 'lat': 40.699607, 'lng':...  ...     United States
# 2  [{'label': 'display', 'lat': 40.70356930142193...  ...     United States
# 3  [{'label': 'display', 'lat': 40.71997833251953...  ...     United States
# 4  [{'label': 'display', 'lat': 40.7503662109375,...  ...     United States
#
#                            location.formattedAddress delivery.id  \
# 0  [93 1st Ave (btwn 5th & 6th St), New York, NY ...     2208366
# 1   [46 Henry St, Brooklyn, NY 11201, United States]      266126
# 2  [60 Pearl St (Broad St.), New York, NY 10004, ...      263979
# 3  [369 Broome St, New York, NY 10013, United Sta...         NaN
# 4   [338 9th Ave, New York, NY 10001, United States]         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0  https://www.seamless.com/menu/panna2-garden-in...               seamless
# 1  https://www.seamless.com/menu/asya-46-henry-st...               seamless
# 2  https://www.seamless.com/menu/bombays-indian-r...               seamless
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#                 delivery.provider.icon.name venuePage.id location.neighborhood
# 0  /delivery_provider_seamless_20180129.png    149505937                   NaN
# 1  /delivery_provider_seamless_20180129.png     94617937                   NaN
# 2  /delivery_provider_seamless_20180129.png     93243558                   NaN
# 3                                       NaN          NaN                   NaN
# 4                                       NaN          NaN                   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                   Panna II Garden Indian Restaurant
# 1                              Asya Indian Restaurant
# 2                          Bombay's Indian Restaurant
# 3                                   Indian Restaurant
# 4                                   Indian Restaurant
# 5                             Dhaka Indian Restaurant
# 6                           Kanan's Indian Restaurant
# 7                               Joy Indian Restaurant
# 8                             Sapid Indian Restaurant
# 9               Joy Curry & Tandoor Indian Restaurant
# 10                              New Shezan Restaurant
# 11                     Indian Biryani Delights (Cart)
# 12                          Indian King Briyani House
# 13                                   Tamarind TriBeCa
# 14                          O'Hara's Restaurant & Pub
# 15                                     Indian Express
# 16                      A Saffron Thread Fresh Indian
# 17                    Mudville Restaurant & Tap House
# 18                       TJ Byrnes Bar and Restaurant
# 19          Indian Beautiful Art (IBA) Crafts PVT Ltd
# 20                      Bismilla Indian Biryani House
# 21          Indian Beautiful Art (IBA) Crafts PVT Ltd
# 22                                 Waverly Restaurant
# 23                                         McDonald's
# 24                           Amore's Pizza Restaurant
# 25                        Kaña Tapas Bar & Restaurant
# 26            Wing Kee WK Restaurant 榮記飯店 (former 69)
# 27                                Junior's Restaurant
# 28                             Gold Flower Restaurant
# 29                           East Broadway Restaurant
# 30  National Museum of the American Indian Museum ...
# 31                               Ruchi Indian Cuisine
# 32                                 Win Won Restaurant
# 33                     Golden Unicorn Restaurant 麒麟金閣
# 34                                Amin Indian Cuisine
# 35                                Arturo's Restaurant
# 36                                   Frank Restaurant
# 37                                   Baluchi's Indian
# 38                       East Boat Seafood Restaurant
# 39                              Chili's Indian Cusine
# 40                  88 Reach House chinese restaurant
# 41             Great Fortune Chinese Restaurant 聚旺茶餐廳
# 42               Vatan Pure Vegetarian Indian Cuisine
# 43                                 Su Hang Restaurant
# 44                           Romi Restaurant & Lounge
# 45                               Aahar Indian Cuisine
# 46                                   China Restaurant
# 47                               Hadramout Restaurant
# 48                                      Swagat Indian
# 49                               smart indian cuisine
#
#                    categories                     address  \
# 0           Indian Restaurant                  93 1st Ave
# 1           Indian Restaurant                 46 Henry St
# 2           Indian Restaurant                 60 Pearl St
# 3           Indian Restaurant               369 Broome St
# 4                        Food                 338 9th Ave
# 5           Indian Restaurant            148 Atlantic Ave
# 6           Indian Restaurant                 452 3rd Ave
# 7           Indian Restaurant            301 Flatbush Ave
# 8           Indian Restaurant          595 Washington Ave
# 9           Indian Restaurant                32 W 39th St
# 10  Middle Eastern Restaurant               183 Church St
# 11                 Food Truck                    Water St
# 12                 Food Truck                140 Broadway
# 13          Indian Restaurant                99 Hudson St
# 14                        Pub                120 Cedar St
# 15          Indian Restaurant                18 Murray St
# 16          Indian Restaurant              98 Chambers St
# 17                Wings Joint             126 Chambers St
# 18                 Restaurant                77 Fulton St
# 19             Clothing Store               100 Church St
# 20                 Food Truck                         NaN
# 21              Design Studio               100 Church St
# 22                      Diner  385 Avenue of the Americas
# 23       Fast Food Restaurant                 102 1st Ave
# 24                Pizza Place             147 Chambers St
# 25                        Bar              324 Spring St.
# 26         Chinese Restaurant                69 Bayard St
# 27                      Diner     386 Flatbush Avenue Ext
# 28                  Nightclub                 9 Doyers St
# 29           Asian Restaurant               94 E Broadway
# 30              Souvenir Shop               1 Bowling Grn
# 31          Indian Restaurant                120 Cedar St
# 32         Chinese Restaurant               10 Liberty Pl
# 33         Dim Sum Restaurant               18 E Broadway
# 34          Indian Restaurant              235 Dekalb Ave
# 35         Italian Restaurant            106 W Houston St
# 36         Italian Restaurant                  88 2nd Ave
# 37          Indian Restaurant           176 Church Street
# 38         Seafood Restaurant               72 Kenmare St
# 39    North Indian Restaurant                123 Allen St
# 40         Chinese Restaurant              88 Division St
# 41       Cantonese Restaurant              5 Catherine St
# 42          Indian Restaurant              808 Newark Ave
# 43         Chinese Restaurant     103 Washington St Apt 2
# 44                     Lounge                19 Rector St
# 45          Indian Restaurant                10 Murray St
# 46         Chinese Restaurant                 50 Henry St
# 47  Middle Eastern Restaurant            172 Atlantic Ave
# 48          Indian Restaurant               205 W 29th St
# 49          Indian Restaurant                53 Nassau St
#
#                          crossStreet        lat        lng  \
# 0                  btwn 5th & 6th St  40.726273 -73.986273
# 1                                NaN  40.699607 -73.992110
# 2                          Broad St.  40.703569 -74.011141
# 3                                NaN  40.719978 -73.995903
# 4                                NaN  40.750366 -73.998138
# 5                                NaN  40.690147 -73.994926
# 6                         9th Street  40.671891 -73.990940
# 7                        Prospect Pl  40.678788 -73.973581
# 8                 btw Pacific & Dean  40.679789 -73.964170
# 9                            6th Ave  40.752385 -73.984045
# 10            btwn Duane & Reade St.  40.715789 -74.007227
# 11        btwn Maiden Lane & Pine St  40.713165 -74.010219
# 12                               NaN  40.709167 -74.010626
# 13                    at Franklin St  40.719211 -74.008727
# 14                  at Greenwich St.  40.709894 -74.012836
# 15                        Church St.  40.713413 -74.008469
# 16                      at Church St  40.714823 -74.007689
# 17       btwn W Broadway & Church St  40.715209 -74.008923
# 18                           Gold St  40.709233 -74.003747
# 19                               NaN  40.712281 -74.010129
# 20                               NaN  40.715357 -74.011315
# 21                               NaN  40.716135 -74.006610
# 22                    at Waverly Pl.  40.733012 -74.000124
# 23                 btwn 5th & 6th St  40.726504 -73.985804
# 24                     Hudson Street  40.715860 -74.009888
# 25     btw Greenwhich and Washington  40.726029 -74.009280
# 26  Mott Street And Elizabeth Street  40.715565 -73.998258
# 27                     at DeKalb Ave  40.690011 -73.981734
# 28                               NaN  40.714351 -73.998213
# 29                    at Eldridge ST  40.713954 -73.993579
# 30                               NaN  40.704048 -74.013737
# 31  btwn Greenwich St. & Trinity Pl.  40.709962 -74.012969
# 32                       Maiden Lane  40.709193 -74.009344
# 33                   at Catherine St  40.713629 -73.997230
# 34                   at Clermont Ave  40.689535 -73.969788
# 35                   at Thompson St.  40.727407 -74.000378
# 36                       at E 5th St  40.726939 -73.988899
# 37   between Duane and Reade Streets  40.715672 -74.007652
# 38                               NaN  40.720955 -73.996300
# 39   btwn Delancey St & Rivington St  40.719720 -73.990134
# 40                    Eldrige street  40.714468 -73.993727
# 41      btwn E Broadway & Chatham Sq  40.713875 -73.997280
# 42                               NaN  40.735603 -74.066612
# 43                         Rector St  40.708363 -74.014046
# 44                 at Washington St.  40.707970 -74.013779
# 45                          Broadway  40.713307 -74.007994
# 46                               NaN  40.712715 -73.995529
# 47          btwn Court & Clinton St.  40.690030 -73.993784
# 48                           7th Ave  40.748046 -73.993108
# 49             maiden lane & liberty  40.709022 -74.009117
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 40.72627299004598...      2246      10003
# 1   [{'label': 'display', 'lat': 40.699607, 'lng':...      1873      11201
# 2   [{'label': 'display', 'lat': 40.70356930142193...      1107      10004
# 3   [{'label': 'display', 'lat': 40.71997833251953...      1174      10013
# 4   [{'label': 'display', 'lat': 40.7503662109375,...      4242      10001
# 5   [{'label': 'display', 'lat': 40.69014739990234...      2682      11201
# 6   [{'label': 'display', 'lat': 40.67189099999999...      4720      11215
# 7   [{'label': 'display', 'lat': 40.67878769589125...      4665      11217
# 8   [{'label': 'display', 'lat': 40.67978864648759...      5091      11238
# 9   [{'label': 'display', 'lat': 40.75238509631068...      4787      10018
# 10  [{'label': 'display', 'lat': 40.71578949233164...       355      10007
# 11  [{'label': 'display', 'lat': 40.71316451366987...       358      10005
# 12  [{'label': 'display', 'lat': 40.70916650382646...       555      10005
# 13  [{'label': 'display', 'lat': 40.71921117375622...       757      10013
# 14  [{'label': 'display', 'lat': 40.70989378141622...       656      10006
# 15  [{'label': 'display', 'lat': 40.71341323852539...       220      10007
# 16  [{'label': 'display', 'lat': 40.71482256030567...       272      10007
# 17  [{'label': 'entrance', 'lat': 40.715239, 'lng'...       369      10007
# 18  [{'label': 'display', 'lat': 40.70923312629616...       433      10038
# 19  [{'label': 'display', 'lat': 40.71228057311295...       350      10007
# 20  [{'label': 'display', 'lat': 40.715357202741, ...       534      10007
# 21  [{'label': 'display', 'lat': 40.71613521878094...       382      10007
# 22  [{'label': 'display', 'lat': 40.73301202815689...      2312      10014
# 23  [{'label': 'entrance', 'lat': 40.726483, 'lng'...      2293      10009
# 24  [{'label': 'display', 'lat': 40.71585960614924...       477      10007
# 25  [{'label': 'display', 'lat': 40.72602896316270...      1506      10013
# 26  [{'label': 'display', 'lat': 40.71556547601636...       726      10013
# 27  [{'label': 'display', 'lat': 40.69001145156075...      3254      11201
# 28  [{'label': 'display', 'lat': 40.714351, 'lng':...       682      10013
# 29  [{'label': 'display', 'lat': 40.713954, 'lng':...      1058      10002
# 30  [{'label': 'display', 'lat': 40.704048, 'lng':...      1165      10004
# 31  [{'label': 'display', 'lat': 40.70996196046026...       662      10006
# 32  [{'label': 'display', 'lat': 40.709193, 'lng':...       483      10038
# 33  [{'label': 'display', 'lat': 40.71362850464683...       748      10002
# 34  [{'label': 'display', 'lat': 40.68953511109607...      4001      11205
# 35  [{'label': 'display', 'lat': 40.727407, 'lng':...      1701      10012
# 36  [{'label': 'display', 'lat': 40.7269388318875,...      2141      10003
# 37  [{'label': 'display', 'lat': 40.71567153930664...       355        NaN
# 38  [{'label': 'display', 'lat': 40.72095489501953...      1229      10012
# 39  [{'label': 'display', 'lat': 40.71972045796349...      1549      10002
# 40  [{'label': 'display', 'lat': 40.714468, 'lng':...      1054      10002
# 41  [{'label': 'display', 'lat': 40.713875, 'lng':...       748      10038
# 42  [{'label': 'display', 'lat': 40.73560333251953...      5711      07306
# 43  [{'label': 'display', 'lat': 40.7083625793457,...       833      10006
# 44  [{'label': 'display', 'lat': 40.70796966552734...       842      10006
# 45  [{'label': 'display', 'lat': 40.71330656515891...       178      10007
# 46  [{'label': 'entrance', 'lat': 40.712877, 'lng'...       884      10002
# 47                                                NaN      2729      11201
# 48  [{'label': 'display', 'lat': 40.74804551427938...      4079      10001
# 49  [{'label': 'display', 'lat': 40.709022, 'lng':...       488      10038
#
#     cc           city state        country  \
# 0   US       New York    NY  United States
# 1   US       Brooklyn    NY  United States
# 2   US       New York    NY  United States
# 3   US       New York    NY  United States
# 4   US       New York    NY  United States
# 5   US       Brooklyn    NY  United States
# 6   US       Brooklyn    NY  United States
# 7   US       Brooklyn    NY  United States
# 8   US       Brooklyn    NY  United States
# 9   US       New York    NY  United States
# 10  US       New York    NY  United States
# 11  US       New York    NY  United States
# 12  US       New York    NY  United States
# 13  US       New York    NY  United States
# 14  US       New York    NY  United States
# 15  US       New York    NY  United States
# 16  US       New York    NY  United States
# 17  US       New York    NY  United States
# 18  US       New York    NY  United States
# 19  US       New York    NY  United States
# 20  US       New York    NY  United States
# 21  US       New York    NY  United States
# 22  US       New York    NY  United States
# 23  US       New York    NY  United States
# 24  US       New York    NY  United States
# 25  US  South Village    NY  United States
# 26  US       New York    NY  United States
# 27  US       Brooklyn    NY  United States
# 28  US       New York    NY  United States
# 29  US       New York    NY  United States
# 30  US       New York    NY  United States
# 31  US       New York    NY  United States
# 32  US       New York    NY  United States
# 33  US       New York    NY  United States
# 34  US       Brooklyn    NY  United States
# 35  US       New York    NY  United States
# 36  US       New York    NY  United States
# 37  US       New York    NY  United States
# 38  US       New York    NY  United States
# 39  US       New York    NY  United States
# 40  US       New York    NY  United States
# 41  US       New York    NY  United States
# 42  US    Jersey City    NJ  United States
# 43  US       New York    NY  United States
# 44  US       New York    NY  United States
# 45  US       New York    NY  United States
# 46  US       New York    NY  United States
# 47  US       Brooklyn    NY  United States
# 48  US       New York    NY  United States
# 49  US       New York    NY  United States
#
#                                      formattedAddress        neighborhood  \
# 0   [93 1st Ave (btwn 5th & 6th St), New York, NY ...                 NaN
# 1    [46 Henry St, Brooklyn, NY 11201, United States]                 NaN
# 2   [60 Pearl St (Broad St.), New York, NY 10004, ...                 NaN
# 3   [369 Broome St, New York, NY 10013, United Sta...                 NaN
# 4    [338 9th Ave, New York, NY 10001, United States]                 NaN
# 5   [148 Atlantic Ave, Brooklyn, NY 11201, United ...                 NaN
# 6   [452 3rd Ave (9th Street), Brooklyn, NY 11215,...                 NaN
# 7   [301 Flatbush Ave (Prospect Pl), Brooklyn, NY ...                 NaN
# 8   [595 Washington Ave (btw Pacific & Dean), Broo...                 NaN
# 9   [32 W 39th St (6th Ave), New York, NY 10018, U...                 NaN
# 10  [183 Church St (btwn Duane & Reade St.), New Y...                 NaN
# 11  [Water St (btwn Maiden Lane & Pine St), New Yo...                 NaN
# 12  [140 Broadway, New York, NY 10005, United States]  Financial District
# 13  [99 Hudson St (at Franklin St), New York, NY 1...                 NaN
# 14  [120 Cedar St (at Greenwich St.), New York, NY...                 NaN
# 15  [18 Murray St (Church St.), New York, NY 10007...                 NaN
# 16  [98 Chambers St (at Church St), New York, NY 1...                 NaN
# 17  [126 Chambers St (btwn W Broadway & Church St)...                 NaN
# 18  [77 Fulton St (Gold St), New York, NY 10038, U...                 NaN
# 19  [100 Church St, New York, NY 10007, United Sta...                 NaN
# 20                [New York, NY 10007, United States]                 NaN
# 21  [100 Church St, New York, NY 10007, United Sta...                 NaN
# 22  [385 Avenue of the Americas (at Waverly Pl.), ...                 NaN
# 23  [102 1st Ave (btwn 5th & 6th St), New York, NY...                 NaN
# 24  [147 Chambers St (Hudson Street), New York, NY...                 NaN
# 25  [324 Spring St. (btw Greenwhich and Washington...                 NaN
# 26  [69 Bayard St (Mott Street And Elizabeth Stree...                 NaN
# 27  [386 Flatbush Avenue Ext (at DeKalb Ave), Broo...   Downtown Brooklyn
# 28   [9 Doyers St, New York, NY 10013, United States]                 NaN
# 29  [94 E Broadway (at Eldridge ST), New York, NY ...                 NaN
# 30  [1 Bowling Grn, New York, NY 10004, United Sta...                 NaN
# 31  [120 Cedar St (btwn Greenwich St. & Trinity Pl...                 NaN
# 32  [10 Liberty Pl (Maiden Lane), New York, NY 100...                 NaN
# 33  [18 E Broadway (at Catherine St), New York, NY...                 NaN
# 34  [235 Dekalb Ave (at Clermont Ave), Brooklyn, N...                 NaN
# 35  [106 W Houston St (at Thompson St.), New York,...                 NaN
# 36  [88 2nd Ave (at E 5th St), New York, NY 10003,...                 NaN
# 37  [176 Church Street (between Duane and Reade St...                 NaN
# 38  [72 Kenmare St, New York, NY 10012, United Sta...                 NaN
# 39  [123 Allen St (btwn Delancey St & Rivington St...                 NaN
# 40  [88 Division St (Eldrige street), New York, NY...                 NaN
# 41  [5 Catherine St (btwn E Broadway & Chatham Sq)...                 NaN
# 42  [808 Newark Ave, Jersey City, NJ 07306, United...                 NaN
# 43  [103 Washington St Apt 2 (Rector St), New York...                 NaN
# 44  [19 Rector St (at Washington St.), New York, N...                 NaN
# 45  [10 Murray St (Broadway), New York, NY 10007, ...                 NaN
# 46   [50 Henry St, New York, NY 10002, United States]                 NaN
# 47  [172 Atlantic Ave (btwn Court & Clinton St.), ...                 NaN
# 48  [205 W 29th St (7th Ave), New York, NY 10001, ...                 NaN
# 49  [53 Nassau St (maiden lane & liberty), New Yor...                 NaN
#
#                           id
# 0   4116be80f964a520f90b1fe3
# 1   506a2625498e3c434686abbc
# 2   4c17b29b838020a1fd0de361
# 3   4d0e6159bf0c8eec2188282a
# 4   4f32a9c119836c91c7eda319
# 5   4e4de5fbbd4101d0d79da9d0
# 6   52f18573498ec2c34e830ffd
# 7   4a7a2112f964a5209ee81fe3
# 8   4c673e729cb82d7f024593d2
# 9   5023ff6ce4b06e8a945ea64a
# 10  4c4890da1879c9b6cce6e143
# 11  5072fe2eb0ed0fcce2497f30
# 12  573f435b498e03b8bb8582c7
# 13  4bbb9dbded7776b0e1ad3e51
# 14  49f125dcf964a52091691fe3
# 15  4a948b83f964a520f32120e3
# 16  510aad1ae4b0bfb2583169b9
# 17  45e5c256f964a52046431fe3
# 18  4b4fdfc8f964a520801827e3
# 19  574eab2a498e3f5530cfdbca
# 20  5d18e90b96ba5e00232c527f
# 21  574e8ba2cd10da9c722374fb
# 22  43bfd385f964a520232d1fe3
# 23  4b87d979f964a5201bcf31e3
# 24  4bc238adf8219c744286b410
# 25  3fd66200f964a5202feb1ee3
# 26  56fd4c5e498e389de05f8b85
# 27  3fd66200f964a5207cf11ee3
# 28  4c00acf98c1076b004982071
# 29  4c136388a1010f476c874a18
# 30  54a4690e498e43a77f503eba
# 31  4b12cb6ff964a5204a8e23e3
# 32  4b88199af964a520e6df31e3
# 33  3fd66200f964a520ece31ee3
# 34  4b44db0bf964a5204dfe25e3
# 35  3fd66200f964a5209ae31ee3
# 36  3fd66200f964a5204de41ee3
# 37  5730b7a9498ef7b05c09c07f
# 38  4b9c3bc7f964a5206d5736e3
# 39  5632cf63498e155da31ebd2b
# 40  4e4463cf52b18fcc799a9761
# 41  58aa398b14fb41097a0cf923
# 42  5e71cb23abf70b00087b749e
# 43  575808cf38fa9ce070c7ce1b
# 44  40fc6080f964a520040b1fe3
# 45  575dea4c498e2739e43a27e2
# 46  4f451ae719836ed00198a204
# 47  4a598897f964a52071b91fe3
# 48  4ae015bff964a5202b7e21e3
# 49  50a5221fe4b0dea0468d43d1

# %%
dataframe_filtered.name
# Out:
# 0                     Panna II Garden Indian Restaurant
# 1                                Asya Indian Restaurant
# 2                            Bombay's Indian Restaurant
# 3                                     Indian Restaurant
# 4                                     Indian Restaurant
# 5                               Dhaka Indian Restaurant
# 6                             Kanan's Indian Restaurant
# 7                                 Joy Indian Restaurant
# 8                               Sapid Indian Restaurant
# 9                 Joy Curry & Tandoor Indian Restaurant
# 10                                New Shezan Restaurant
# 11                       Indian Biryani Delights (Cart)
# 12                            Indian King Briyani House
# 13                                     Tamarind TriBeCa
# 14                            O'Hara's Restaurant & Pub
# 15                                       Indian Express
# 16                        A Saffron Thread Fresh Indian
# 17                      Mudville Restaurant & Tap House
# 18                         TJ Byrnes Bar and Restaurant
# 19            Indian Beautiful Art (IBA) Crafts PVT Ltd
# 20                        Bismilla Indian Biryani House
# 21            Indian Beautiful Art (IBA) Crafts PVT Ltd
# 22                                   Waverly Restaurant
# 23                                           McDonald's
# 24                             Amore's Pizza Restaurant
# 25                          Kaña Tapas Bar & Restaurant
# 26              Wing Kee WK Restaurant 榮記飯店 (former 69)
# 27                                  Junior's Restaurant
# 28                               Gold Flower Restaurant
# 29                             East Broadway Restaurant
# 30    National Museum of the American Indian Museum ...
# 31                                 Ruchi Indian Cuisine
# 32                                   Win Won Restaurant
# 33                       Golden Unicorn Restaurant 麒麟金閣
# 34                                  Amin Indian Cuisine
# 35                                  Arturo's Restaurant
# 36                                     Frank Restaurant
# 37                                     Baluchi's Indian
# 38                         East Boat Seafood Restaurant
# 39                                Chili's Indian Cusine
# 40                    88 Reach House chinese restaurant
# 41               Great Fortune Chinese Restaurant 聚旺茶餐廳
# 42                 Vatan Pure Vegetarian Indian Cuisine
# 43                                   Su Hang Restaurant
# 44                             Romi Restaurant & Lounge
# 45                                 Aahar Indian Cuisine
# 46                                     China Restaurant
# 47                                 Hadramout Restaurant
# 48                                        Swagat Indian
# 49                                 smart indian cuisine
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel



# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

#display map
venues_map
#venues_map.save(r'C:\Users\sures\Desktop\capstone\myfolium.png')
# Out:
# Folium installed
# Libraries imported.
# Your credentails:
# CLIENT_ID: 22CNRY0G2PZV00WLW12BFAC5KG0ZPB1CDZ2HQ05HNTO203UL
# CLIENT_SECRET:LRV2TWX04RQ4WTTGSVLJS4MBTVW5GRUOK4ASBAAOH1JPGHEN
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.
# Indian restaurant .... OK!
# <ipython-input-6-0099a2dd0c28>:54: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0f0fbfcbe59548ceb2e49716c9cf9537%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0f0fbfcbe59548ceb2e49716c9cf9537%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0f0fbfcbe59548ceb2e49716c9cf9537%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0f0fbfcbe59548ceb2e49716c9cf9537%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7127281%2C%20-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
